# %%
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt

# %%
img_path = '/home/luo3300612/Workspace/PycharmWS/mySuperPoint/dataset/data/draw_checkerboard/images/training/0.png'
img = Image.open(img_path)

# %%
plt.axis('off')
plt.imshow(img,cmap='gray')

# %%
T = transforms.Compose([transforms.ColorJitter(0.7,0.4,0.2,0.2)])

# %%
img_after = T(img)

# %%
plt.imshow(img_after,cmap='gray')
